# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Gen ai\tf215_env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sent=["the glass of milk",
       "the glass of juice",
       "the cup of tea",
       "i am a good boy",
       "i am a good student",]

# %%
voc_size=10000

# %%
onehot_represent=[one_hot(words, voc_size) for words in sent]
onehot_represent
# Out:
# [[8761, 3901, 5157, 6082],
#  [8761, 3901, 5157, 414],
#  [8761, 4181, 5157, 4729],
#  [1956, 767, 3993, 3557, 3311],
#  [1956, 767, 3993, 3557, 9194]]

# %%
from tensorflow.keras.layers import Embedding
import numpy as np
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length=8 
embedded_docs=pad_sequences(onehot_represent, padding='pre', maxlen=sent_length)
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 8761, 3901, 5157, 6082],
#        [   0,    0,    0,    0, 8761, 3901, 5157,  414],
#        [   0,    0,    0,    0, 8761, 4181, 5157, 4729],
#        [   0,    0,    0, 1956,  767, 3993, 3557, 3311],
#        [   0,    0,    0, 1956,  767, 3993, 3557, 9194]])

# %%
dim=10  # Dimension of the embedding vector

# %%
model=Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_length))
model.compile('adam', 'mse')
# Out:
# WARNING:tensorflow:From c:\Gen ai\tf215_env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Gen ai\tf215_env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.build(input_shape=(None, sent_length))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 159ms/step
# array([[[-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [-0.03264693,  0.03527066, -0.01943412, -0.02976499,
#          -0.0378686 ,  0.00578428,  0.03236714,  0.04730355,
#          -0.0024531 ,  0.01400323],
#         [ 0.02663633, -0.02666885,  0.02284037, -0.01194421,
#          -0.00795584,  0.01314804, -0.02381765, -0.02087361,
#          -0.01973127,  0.02620916],
#         [ 0.04267272,  0.0238614 , -0.01972777,  0.02754844,
#          -0.00504619, -0.02085314, -0.01049489, -0.02238663,
#           0.02662757,  0.02934697],
#         [-0.0302331 ,  0.04184261, -0.04179772,  0.01824757,
#           0.00258361,  0.04776262, -0.03815414,  0.03449725,
#          -0.00719991,  0.00408746]],
#
#        [[-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#         [-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [ 0.04850103, -0.03088647,  0.02988781,  0.03816352,
#          -0.02300592, -0.04198642,  0.0281474 , -0.04085267,
#           0.00099849, -0.03523275],
#         [-0.02680731, -0.02904446,  0.00088377,  0.00457529,
#          -0.03924293, -0.02775537, -0.02835377, -0.02634794,
#          -0.00282782, -0.00813071],
#         [-0.04460255,  0.02611888,  0.0141933 , -0.0493904 ,
#           0.00266922,  0.02580852,  0.04991702, -0.02030738,
#          -0.03544084,  0.02603319],
#         [ 0.03035643, -0.00948774, -0.02962229, -0.01634349,
#          -0.03033379, -0.04690043,  0.0206674 ,  0.01047807,
#          -0.01437961,  0.01260925],
#         [ 0.0248977 , -0.00379575, -0.01536269,  0.00091143,
#          -0.02120466, -0.00676782,  0.03841705,  0.02561839,
#           0.02662059,  0.00228081]],
#
#        [[-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [-0.02859638, -0.03682548, -0.02790936,  0.02170786,
#           0.01560945, -0.02114328, -0.0245645 , -0.04416107,
#           0.00494806, -0.02147055],
#         [ 0.04850103, -0.03088647,  0.02988781,  0.03816352,
#          -0.02300592, -0.04198642,  0.0281474 , -0.04085267,
#           0.00099849, -0.03523275],
#         [-0.02680731, -0.02904446,  0.00088377,  0.00457529,
#          -0.03924293, -0.02775537, -0.02835377, -0.02634794,
#          -0.00282782, -0.00813071],
#         [-0.04460255,  0.02611888,  0.0141933 , -0.0493904 ,
#           0.00266922,  0.02580852,  0.04991702, -0.02030738,
#          -0.03544084,  0.02603319],
#         [ 0.03035643, -0.00948774, -0.02962229, -0.01634349,
#          -0.03033379, -0.04690043,  0.0206674 ,  0.01047807,
#          -0.01437961,  0.01260925],
#         [ 0.02585549,  0.03563556, -0.02510861, -0.02206802,
#          -0.04260926, -0.0204741 , -0.02244533, -0.02685489,
#          -0.00261295, -0.02415684]]], dtype=float32)

# %%
import tensorflow as tf
import keras

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
# Out:
# TensorFlow version: 2.15.0
# Keras version: 2.15.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0
